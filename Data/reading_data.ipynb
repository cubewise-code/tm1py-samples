# %% [markdown]
# <h1 style="font-size:42px; text-align:center; margin-bottom:30px;"><span style="color:SteelBlue">TM1py:</span>Reading Data</h1>
# <hr>
# Going through all the different ways to get data into your Python scripts

# %% [markdown]
# ## Part 1: Reading data from a CSV file
# Introduction to [pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
#import pandas to get data from csv file
import pandas as pd

# %%
# pd.read_csv will store the information into a pandas dataframe called df
df = pd.read_csv('reading_data.csv')

# %%
#A pandas dataframe has lots of cool pre-built functions such as:
# print the result
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  1/12/2010 8:26       2.55     17850.0  United Kingdom
# 1  1/12/2010 8:26       3.39     17850.0  United Kingdom
# 2  1/12/2010 8:26       2.75     17850.0  United Kingdom
# 3  1/12/2010 8:26       3.39     17850.0  United Kingdom
# 4  1/12/2010 8:26       3.39     17850.0  United Kingdom

# %%
#write data to csv
df.to_csv('my_new_filePyPal.csv')

# %%
# Find all unique values for one column
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania'], dtype=object)

# %% [markdown]
# <h2> Part 2: Reading data from TM1 </h2>
# <span> Going through all TM1py options to load data from TM1 into our Jupyter notebook</span>

# %% [markdown]
# <h3>Setting up connection to TM1</h3>

# %%
#import TM1py services
from TM1py.Services import TM1Service
from TM1py.Utils import Utils

# %%
#TM1 credentials
ADDRESS = "localhost"
PORT = 8009
USER = "admin"
PWD = "apple"
SSL = True

# %%
#Connect to the TM1 instance
tm1 = TM1Service(address=ADDRESS, port=PORT, user=USER, password=PWD, ssl=SSL)

# %%
# Cube view used in this notbook
cube_name = 'Bike Shares'
view_name = '2014 to 2017 Counts by Day'

# %% [markdown]
# ## Getting the view as map of coordinates and values
# - **Use Case:** Get the values with all intersections

# %%
# query first 5 cells from the cube view as coordinate-cell dictionary
cells = tm1.cubes.cells.execute_view(cube_name=cube_name, view_name=view_name, private=False, top=5)
cells
# Out:
# {('[Version].[Version].[Actual]', '[Date].[Date].[2014-01-01]', '[City].[City].[NYC]', '[Bike Shares Measure].[Bike Shares Measure].[Count]'): {'Value': 6059}, ('[Version].[Version].[Actual]', '[Date].[Date].[2014-01-01]', '[City].[City].[Chicago]', '[Bike Shares Measure].[Bike Shares Measure].[Count]'): {'Value': 123}, ('[Version].[Version].[Actual]', '[Date].[Date].[2014-01-01]', '[City].[City].[Washington]', '[Bike Shares Measure].[Bike Shares Measure].[Count]'): {'Value': 3011}, ('[Version].[Version].[Actual]', '[Date].[Date].[2014-01-02]', '[City].[City].[NYC]', '[Bike Shares Measure].[Bike Shares Measure].[Count]'): {'Value': 8600}, ('[Version].[Version].[Actual]', '[Date].[Date].[2014-01-02]', '[City].[City].[Chicago]', '[Bike Shares Measure].[Bike Shares Measure].[Count]'): {'Value': 112}}

# %%
# print first entries from coordinates-cell dictionary instead of [Version].[Version].[Actual] returns Actual
for element_unique_names, cell in cells.items():
    # extract element names from unique-element-names
    element_names = Utils.element_names_from_element_unique_names(
        element_unique_names=element_unique_names)
    # take value from cell
    value = cell["Value"]
    print(element_names, value)
# Out:
# ('Actual', '2014-01-01', 'NYC', 'Count') 6059
# ('Actual', '2014-01-01', 'Chicago', 'Count') 123
# ('Actual', '2014-01-01', 'Washington', 'Count') 3011
# ('Actual', '2014-01-02', 'NYC', 'Count') 8600
# ('Actual', '2014-01-02', 'Chicago', 'Count') 112

# %% [markdown]
# ## Getting the number of cells
# - **Use Case:** Check how many cells are you going to work with
# - **Note**: Very fast

# %%
#tm1.cubes.cells.execute_view_csv or tm1.cubes.cells.execute_mdx_csv
# %time
df_cellcount= tm1.cubes.cells.execute_view_cellcount(cube_name=cube_name, view_name=view_name, private=False)
# Out:
# Wall time: 0 ns

# %%
df_cellcount
# Out:
# 4383

# %% [markdown]
# ## Getting data as CSV fomat
# - **Use Case**: Get your data as CSV format
# - **Note**: Very fast

# %%
#tm1.cubes.cells.execute_view_csv or tm1.cubes.cells.execute_mdx_csv
# %time
csv = tm1.cubes.cells.execute_view_csv(cube_name=cube_name, view_name=view_name, private=False)
# Out:
# Wall time: 0 ns

# %%
#diplay the result as CSV format
csv[0:200]
# Out:
# 'Date,City,Value\r\n2014-01-01,NYC,6059\r\n2014-01-01,Chicago,123\r\n2014-01-01,Washington,3011\r\n2014-01-02,NYC,8600\r\n2014-01-02,Chicago,112\r\n2014-01-02,Washington,3316\r\n2014-01-03,NYC,1144\r\n2014-01-03,Chica'

# %%
#diplay first 10 lines of the result
for line in csv.split("\r\n")[0:10]:
    print(line)
# Out:
# Date,City,Value
# 2014-01-01,NYC,6059
# 2014-01-01,Chicago,123
# 2014-01-01,Washington,3011
# 2014-01-02,NYC,8600
# 2014-01-02,Chicago,112
# 2014-01-02,Washington,3316
# 2014-01-03,NYC,1144
# 2014-01-03,Chicago,6
# 2014-01-03,Washington,1608

# %%
#diplay last 20 lines of the result
for line in csv.split("\r\n")[-10:]:
    print(line)
# Out:
# 2017-12-29,NYC,13759
# 2017-12-29,Chicago,1076
# 2017-12-29,Washington,3088
# 2017-12-30,NYC,5956
# 2017-12-30,Chicago,548
# 2017-12-30,Washington,1876
# 2017-12-31,NYC,6569
# 2017-12-31,Chicago,651
# 2017-12-31,Washington,1437

# %% [markdown]
# ## Getting data as (pandas) dataframe
# - **Use Case**: Get your data as a pandas dataframe
# - **Note**: useful for further data analysis in python

# %%
# %time
df = tm1.cubes.cells.execute_view_dataframe(cube_name=cube_name, view_name=view_name, private=False)
# Out:
# Wall time: 0 ns

# %%
df.head()
# Out:
#          Date        City  Value
# 0  2014-01-01         NYC   6059
# 1  2014-01-01     Chicago    123
# 2  2014-01-01  Washington   3011
# 3  2014-01-02         NYC   8600
# 4  2014-01-02     Chicago    112

# %%
df.to_csv(view_name+"Pypal.csv")

# %% [markdown]
# ## Getting data as (pandas) pivot dataframe
# - **Use Case**: Get your data as a pandas dataframe following your view structure
# - **Note**: useful for further data analysis in python

# %%
# %time
df_pivot = tm1.cubes.cells.execute_view_dataframe_pivot(cube_name=cube_name, view_name=view_name, private=False)
# Out:
# Wall time: 0 ns

# %%
# print first 5 records
df_pivot.head()
# Out:
#             Values
# City       Chicago     NYC Washington
# Date
# 2014-01-01   123.0  6059.0     3011.0
# 2014-01-02   112.0  8600.0     3316.0
# 2014-01-03     6.0  1144.0     1608.0
# 2014-01-04   205.0  2292.0     2242.0
# 2014-01-05    33.0  2678.0     2060.0

# %%
# print last 5 records
df_pivot.tail()
# Out:
#             Values
# City       Chicago      NYC Washington
# Date
# 2017-12-27  1138.0  16365.0     3321.0
# 2017-12-28  1294.0  13420.0     2866.0
# 2017-12-29  1076.0  13759.0     3088.0
# 2017-12-30   548.0   5956.0     1876.0
# 2017-12-31   651.0   6569.0     1437.0

# %% [markdown]
# ## Getting data in custom JSON format
# - **Use Case**: Query additional information, such as:
#     - Cell is RuleDerived
#     - Cell is Consolidated
#     - Member properties
#     - Attribute Values
#
# - **Note**: very flexible. Not fast.

# %%
# %time
raw_json = tm1.cubes.cells.execute_view_raw(
    cube_name=cube_name, 
    view_name=view_name, 
    private=False, 
    elem_properties=["Type"],
    cell_properties=["RuleDerived", "Value"])
# Out:
# Wall time: 0 ns

# %%
# print full response
raw_json
# Out:
# {'@odata.context': '$metadata#Cellsets(Cube(Name,Dimensions+(Name)),Axes(Tuples+(Members+(Name,Element+(Type)))),Cells(Value,RuleDerived))/$entity',
#  'ID': 'oGuKUDcCAICTAAAg',
#  'Cube': {'Name': 'Bike Shares',
#   'Dimensions': [{'Name': 'Version'},
#    {'Name': 'Date'},
#    {'Name': 'City'},
#    {'Name': 'Bike Shares Measure'}]},
#  'Axes': [{'Ordinal': 0,
#    'Cardinality': 3,
#    'Tuples': [{'Ordinal': 0,
#      'Members': [{'Name': 'NYC', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 1,
#      'Members': [{'Name': 'Chicago', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 2,
#      'Members': [{'Name': 'Washington', 'Element': {'Type': 'Numeric'}}]}]},
#   {'Ordinal': 1,
#    'Cardinality': 1461,
#    'Tuples': [{'Ordinal': 0,
#      'Members': [{'Name': '2014-01-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 1,
#      'Members': [{'Name': '2014-01-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 2,
#      'Members': [{'Name': '2014-01-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 3,
#      'Members': [{'Name': '2014-01-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 4,
#      'Members': [{'Name': '2014-01-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 5,
#      'Members': [{'Name': '2014-01-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 6,
#      'Members': [{'Name': '2014-01-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 7,
#      'Members': [{'Name': '2014-01-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 8,
#      'Members': [{'Name': '2014-01-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 9,
#      'Members': [{'Name': '2014-01-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 10,
#      'Members': [{'Name': '2014-01-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 11,
#      'Members': [{'Name': '2014-01-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 12,
#      'Members': [{'Name': '2014-01-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 13,
#      'Members': [{'Name': '2014-01-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 14,
#      'Members': [{'Name': '2014-01-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 15,
#      'Members': [{'Name': '2014-01-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 16,
#      'Members': [{'Name': '2014-01-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 17,
#      'Members': [{'Name': '2014-01-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 18,
#      'Members': [{'Name': '2014-01-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 19,
#      'Members': [{'Name': '2014-01-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 20,
#      'Members': [{'Name': '2014-01-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 21,
#      'Members': [{'Name': '2014-01-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 22,
#      'Members': [{'Name': '2014-01-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 23,
#      'Members': [{'Name': '2014-01-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 24,
#      'Members': [{'Name': '2014-01-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 25,
#      'Members': [{'Name': '2014-01-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 26,
#      'Members': [{'Name': '2014-01-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 27,
#      'Members': [{'Name': '2014-01-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 28,
#      'Members': [{'Name': '2014-01-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 29,
#      'Members': [{'Name': '2014-01-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 30,
#      'Members': [{'Name': '2014-01-31', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 31,
#      'Members': [{'Name': '2014-02-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 32,
#      'Members': [{'Name': '2014-02-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 33,
#      'Members': [{'Name': '2014-02-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 34,
#      'Members': [{'Name': '2014-02-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 35,
#      'Members': [{'Name': '2014-02-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 36,
#      'Members': [{'Name': '2014-02-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 37,
#      'Members': [{'Name': '2014-02-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 38,
#      'Members': [{'Name': '2014-02-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 39,
#      'Members': [{'Name': '2014-02-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 40,
#      'Members': [{'Name': '2014-02-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 41,
#      'Members': [{'Name': '2014-02-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 42,
#      'Members': [{'Name': '2014-02-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 43,
#      'Members': [{'Name': '2014-02-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 44,
#      'Members': [{'Name': '2014-02-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 45,
#      'Members': [{'Name': '2014-02-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 46,
#      'Members': [{'Name': '2014-02-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 47,
#      'Members': [{'Name': '2014-02-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 48,
#      'Members': [{'Name': '2014-02-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 49,
#      'Members': [{'Name': '2014-02-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 50,
#      'Members': [{'Name': '2014-02-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 51,
#      'Members': [{'Name': '2014-02-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 52,
#      'Members': [{'Name': '2014-02-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 53,
#      'Members': [{'Name': '2014-02-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 54,
#      'Members': [{'Name': '2014-02-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 55,
#      'Members': [{'Name': '2014-02-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 56,
#      'Members': [{'Name': '2014-02-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 57,
#      'Members': [{'Name': '2014-02-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 58,
#      'Members': [{'Name': '2014-02-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 59,
#      'Members': [{'Name': '2014-03-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 60,
#      'Members': [{'Name': '2014-03-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 61,
#      'Members': [{'Name': '2014-03-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 62,
#      'Members': [{'Name': '2014-03-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 63,
#      'Members': [{'Name': '2014-03-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 64,
#      'Members': [{'Name': '2014-03-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 65,
#      'Members': [{'Name': '2014-03-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 66,
#      'Members': [{'Name': '2014-03-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 67,
#      'Members': [{'Name': '2014-03-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 68,
#      'Members': [{'Name': '2014-03-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 69,
#      'Members': [{'Name': '2014-03-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 70,
#      'Members': [{'Name': '2014-03-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 71,
#      'Members': [{'Name': '2014-03-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 72,
#      'Members': [{'Name': '2014-03-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 73,
#      'Members': [{'Name': '2014-03-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 74,
#      'Members': [{'Name': '2014-03-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 75,
#      'Members': [{'Name': '2014-03-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 76,
#      'Members': [{'Name': '2014-03-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 77,
#      'Members': [{'Name': '2014-03-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 78,
#      'Members': [{'Name': '2014-03-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 79,
#      'Members': [{'Name': '2014-03-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 80,
#      'Members': [{'Name': '2014-03-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 81,
#      'Members': [{'Name': '2014-03-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 82,
#      'Members': [{'Name': '2014-03-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 83,
#      'Members': [{'Name': '2014-03-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 84,
#      'Members': [{'Name': '2014-03-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 85,
#      'Members': [{'Name': '2014-03-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 86,
#      'Members': [{'Name': '2014-03-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 87,
#      'Members': [{'Name': '2014-03-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 88,
#      'Members': [{'Name': '2014-03-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 89,
#      'Members': [{'Name': '2014-03-31', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 90,
#      'Members': [{'Name': '2014-04-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 91,
#      'Members': [{'Name': '2014-04-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 92,
#      'Members': [{'Name': '2014-04-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 93,
#      'Members': [{'Name': '2014-04-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 94,
#      'Members': [{'Name': '2014-04-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 95,
#      'Members': [{'Name': '2014-04-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 96,
#      'Members': [{'Name': '2014-04-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 97,
#      'Members': [{'Name': '2014-04-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 98,
#      'Members': [{'Name': '2014-04-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 99,
#      'Members': [{'Name': '2014-04-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 100,
#      'Members': [{'Name': '2014-04-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 101,
#      'Members': [{'Name': '2014-04-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 102,
#      'Members': [{'Name': '2014-04-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 103,
#      'Members': [{'Name': '2014-04-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 104,
#      'Members': [{'Name': '2014-04-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 105,
#      'Members': [{'Name': '2014-04-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 106,
#      'Members': [{'Name': '2014-04-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 107,
#      'Members': [{'Name': '2014-04-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 108,
#      'Members': [{'Name': '2014-04-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 109,
#      'Members': [{'Name': '2014-04-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 110,
#      'Members': [{'Name': '2014-04-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 111,
#      'Members': [{'Name': '2014-04-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 112,
#      'Members': [{'Name': '2014-04-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 113,
#      'Members': [{'Name': '2014-04-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 114,
#      'Members': [{'Name': '2014-04-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 115,
#      'Members': [{'Name': '2014-04-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 116,
#      'Members': [{'Name': '2014-04-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 117,
#      'Members': [{'Name': '2014-04-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 118,
#      'Members': [{'Name': '2014-04-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 119,
#      'Members': [{'Name': '2014-04-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 120,
#      'Members': [{'Name': '2014-05-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 121,
#      'Members': [{'Name': '2014-05-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 122,
#      'Members': [{'Name': '2014-05-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 123,
#      'Members': [{'Name': '2014-05-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 124,
#      'Members': [{'Name': '2014-05-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 125,
#      'Members': [{'Name': '2014-05-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 126,
#      'Members': [{'Name': '2014-05-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 127,
#      'Members': [{'Name': '2014-05-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 128,
#      'Members': [{'Name': '2014-05-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 129,
#      'Members': [{'Name': '2014-05-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 130,
#      'Members': [{'Name': '2014-05-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 131,
#      'Members': [{'Name': '2014-05-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 132,
#      'Members': [{'Name': '2014-05-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 133,
#      'Members': [{'Name': '2014-05-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 134,
#      'Members': [{'Name': '2014-05-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 135,
#      'Members': [{'Name': '2014-05-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 136,
#      'Members': [{'Name': '2014-05-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 137,
#      'Members': [{'Name': '2014-05-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 138,
#      'Members': [{'Name': '2014-05-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 139,
#      'Members': [{'Name': '2014-05-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 140,
#      'Members': [{'Name': '2014-05-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 141,
#      'Members': [{'Name': '2014-05-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 142,
#      'Members': [{'Name': '2014-05-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 143,
#      'Members': [{'Name': '2014-05-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 144,
#      'Members': [{'Name': '2014-05-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 145,
#      'Members': [{'Name': '2014-05-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 146,
#      'Members': [{'Name': '2014-05-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 147,
#      'Members': [{'Name': '2014-05-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 148,
#      'Members': [{'Name': '2014-05-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 149,
#      'Members': [{'Name': '2014-05-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 150,
#      'Members': [{'Name': '2014-05-31', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 151,
#      'Members': [{'Name': '2014-06-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 152,
#      'Members': [{'Name': '2014-06-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 153,
#      'Members': [{'Name': '2014-06-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 154,
#      'Members': [{'Name': '2014-06-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 155,
#      'Members': [{'Name': '2014-06-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 156,
#      'Members': [{'Name': '2014-06-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 157,
#      'Members': [{'Name': '2014-06-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 158,
#      'Members': [{'Name': '2014-06-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 159,
#      'Members': [{'Name': '2014-06-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 160,
#      'Members': [{'Name': '2014-06-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 161,
#      'Members': [{'Name': '2014-06-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 162,
#      'Members': [{'Name': '2014-06-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 163,
#      'Members': [{'Name': '2014-06-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 164,
#      'Members': [{'Name': '2014-06-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 165,
#      'Members': [{'Name': '2014-06-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 166,
#      'Members': [{'Name': '2014-06-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 167,
#      'Members': [{'Name': '2014-06-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 168,
#      'Members': [{'Name': '2014-06-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 169,
#      'Members': [{'Name': '2014-06-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 170,
#      'Members': [{'Name': '2014-06-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 171,
#      'Members': [{'Name': '2014-06-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 172,
#      'Members': [{'Name': '2014-06-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 173,
#      'Members': [{'Name': '2014-06-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 174,
#      'Members': [{'Name': '2014-06-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 175,
#      'Members': [{'Name': '2014-06-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 176,
#      'Members': [{'Name': '2014-06-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 177,
#      'Members': [{'Name': '2014-06-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 178,
#      'Members': [{'Name': '2014-06-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 179,
#      'Members': [{'Name': '2014-06-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 180,
#      'Members': [{'Name': '2014-06-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 181,
#      'Members': [{'Name': '2014-07-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 182,
#      'Members': [{'Name': '2014-07-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 183,
#      'Members': [{'Name': '2014-07-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 184,
#      'Members': [{'Name': '2014-07-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 185,
#      'Members': [{'Name': '2014-07-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 186,
#      'Members': [{'Name': '2014-07-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 187,
#      'Members': [{'Name': '2014-07-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 188,
#      'Members': [{'Name': '2014-07-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 189,
#      'Members': [{'Name': '2014-07-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 190,
#      'Members': [{'Name': '2014-07-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 191,
#      'Members': [{'Name': '2014-07-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 192,
#      'Members': [{'Name': '2014-07-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 193,
#      'Members': [{'Name': '2014-07-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 194,
#      'Members': [{'Name': '2014-07-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 195,
#      'Members': [{'Name': '2014-07-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 196,
#      'Members': [{'Name': '2014-07-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 197,
#      'Members': [{'Name': '2014-07-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 198,
#      'Members': [{'Name': '2014-07-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 199,
#      'Members': [{'Name': '2014-07-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 200,
#      'Members': [{'Name': '2014-07-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 201,
#      'Members': [{'Name': '2014-07-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 202,
#      'Members': [{'Name': '2014-07-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 203,
#      'Members': [{'Name': '2014-07-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 204,
#      'Members': [{'Name': '2014-07-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 205,
#      'Members': [{'Name': '2014-07-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 206,
#      'Members': [{'Name': '2014-07-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 207,
#      'Members': [{'Name': '2014-07-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 208,
#      'Members': [{'Name': '2014-07-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 209,
#      'Members': [{'Name': '2014-07-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 210,
#      'Members': [{'Name': '2014-07-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 211,
#      'Members': [{'Name': '2014-07-31', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 212,
#      'Members': [{'Name': '2014-08-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 213,
#      'Members': [{'Name': '2014-08-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 214,
#      'Members': [{'Name': '2014-08-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 215,
#      'Members': [{'Name': '2014-08-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 216,
#      'Members': [{'Name': '2014-08-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 217,
#      'Members': [{'Name': '2014-08-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 218,
#      'Members': [{'Name': '2014-08-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 219,
#      'Members': [{'Name': '2014-08-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 220,
#      'Members': [{'Name': '2014-08-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 221,
#      'Members': [{'Name': '2014-08-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 222,
#      'Members': [{'Name': '2014-08-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 223,
#      'Members': [{'Name': '2014-08-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 224,
#      'Members': [{'Name': '2014-08-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 225,
#      'Members': [{'Name': '2014-08-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 226,
#      'Members': [{'Name': '2014-08-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 227,
#      'Members': [{'Name': '2014-08-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 228,
#      'Members': [{'Name': '2014-08-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 229,
#      'Members': [{'Name': '2014-08-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 230,
#      'Members': [{'Name': '2014-08-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 231,
#      'Members': [{'Name': '2014-08-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 232,
#      'Members': [{'Name': '2014-08-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 233,
#      'Members': [{'Name': '2014-08-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 234,
#      'Members': [{'Name': '2014-08-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 235,
#      'Members': [{'Name': '2014-08-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 236,
#      'Members': [{'Name': '2014-08-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 237,
#      'Members': [{'Name': '2014-08-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 238,
#      'Members': [{'Name': '2014-08-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 239,
#      'Members': [{'Name': '2014-08-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 240,
#      'Members': [{'Name': '2014-08-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 241,
#      'Members': [{'Name': '2014-08-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 242,
#      'Members': [{'Name': '2014-08-31', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 243,
#      'Members': [{'Name': '2014-09-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 244,
#      'Members': [{'Name': '2014-09-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 245,
#      'Members': [{'Name': '2014-09-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 246,
#      'Members': [{'Name': '2014-09-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 247,
#      'Members': [{'Name': '2014-09-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 248,
#      'Members': [{'Name': '2014-09-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 249,
#      'Members': [{'Name': '2014-09-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 250,
#      'Members': [{'Name': '2014-09-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 251,
#      'Members': [{'Name': '2014-09-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 252,
#      'Members': [{'Name': '2014-09-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 253,
#      'Members': [{'Name': '2014-09-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 254,
#      'Members': [{'Name': '2014-09-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 255,
#      'Members': [{'Name': '2014-09-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 256,
#      'Members': [{'Name': '2014-09-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 257,
#      'Members': [{'Name': '2014-09-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 258,
#      'Members': [{'Name': '2014-09-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 259,
#      'Members': [{'Name': '2014-09-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 260,
#      'Members': [{'Name': '2014-09-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 261,
#      'Members': [{'Name': '2014-09-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 262,
#      'Members': [{'Name': '2014-09-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 263,
#      'Members': [{'Name': '2014-09-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 264,
#      'Members': [{'Name': '2014-09-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 265,
#      'Members': [{'Name': '2014-09-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 266,
#      'Members': [{'Name': '2014-09-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 267,
#      'Members': [{'Name': '2014-09-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 268,
#      'Members': [{'Name': '2014-09-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 269,
#      'Members': [{'Name': '2014-09-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 270,
#      'Members': [{'Name': '2014-09-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 271,
#      'Members': [{'Name': '2014-09-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 272,
#      'Members': [{'Name': '2014-09-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 273,
#      'Members': [{'Name': '2014-10-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 274,
#      'Members': [{'Name': '2014-10-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 275,
#      'Members': [{'Name': '2014-10-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 276,
#      'Members': [{'Name': '2014-10-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 277,
#      'Members': [{'Name': '2014-10-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 278,
#      'Members': [{'Name': '2014-10-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 279,
#      'Members': [{'Name': '2014-10-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 280,
#      'Members': [{'Name': '2014-10-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 281,
#      'Members': [{'Name': '2014-10-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 282,
#      'Members': [{'Name': '2014-10-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 283,
#      'Members': [{'Name': '2014-10-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 284,
#      'Members': [{'Name': '2014-10-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 285,
#      'Members': [{'Name': '2014-10-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 286,
#      'Members': [{'Name': '2014-10-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 287,
#      'Members': [{'Name': '2014-10-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 288,
#      'Members': [{'Name': '2014-10-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 289,
#      'Members': [{'Name': '2014-10-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 290,
#      'Members': [{'Name': '2014-10-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 291,
#      'Members': [{'Name': '2014-10-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 292,
#      'Members': [{'Name': '2014-10-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 293,
#      'Members': [{'Name': '2014-10-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 294,
#      'Members': [{'Name': '2014-10-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 295,
#      'Members': [{'Name': '2014-10-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 296,
#      'Members': [{'Name': '2014-10-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 297,
#      'Members': [{'Name': '2014-10-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 298,
#      'Members': [{'Name': '2014-10-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 299,
#      'Members': [{'Name': '2014-10-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 300,
#      'Members': [{'Name': '2014-10-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 301,
#      'Members': [{'Name': '2014-10-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 302,
#      'Members': [{'Name': '2014-10-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 303,
#      'Members': [{'Name': '2014-10-31', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 304,
#      'Members': [{'Name': '2014-11-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 305,
#      'Members': [{'Name': '2014-11-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 306,
#      'Members': [{'Name': '2014-11-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 307,
#      'Members': [{'Name': '2014-11-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 308,
#      'Members': [{'Name': '2014-11-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 309,
#      'Members': [{'Name': '2014-11-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 310,
#      'Members': [{'Name': '2014-11-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 311,
#      'Members': [{'Name': '2014-11-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 312,
#      'Members': [{'Name': '2014-11-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 313,
#      'Members': [{'Name': '2014-11-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 314,
#      'Members': [{'Name': '2014-11-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 315,
#      'Members': [{'Name': '2014-11-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 316,
#      'Members': [{'Name': '2014-11-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 317,
#      'Members': [{'Name': '2014-11-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 318,
#      'Members': [{'Name': '2014-11-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 319,
#      'Members': [{'Name': '2014-11-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 320,
#      'Members': [{'Name': '2014-11-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 321,
#      'Members': [{'Name': '2014-11-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 322,
#      'Members': [{'Name': '2014-11-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 323,
#      'Members': [{'Name': '2014-11-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 324,
#      'Members': [{'Name': '2014-11-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 325,
#      'Members': [{'Name': '2014-11-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 326,
#      'Members': [{'Name': '2014-11-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 327,
#      'Members': [{'Name': '2014-11-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 328,
#      'Members': [{'Name': '2014-11-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 329,
#      'Members': [{'Name': '2014-11-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 330,
#      'Members': [{'Name': '2014-11-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 331,
#      'Members': [{'Name': '2014-11-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 332,
#      'Members': [{'Name': '2014-11-29', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 333,
#      'Members': [{'Name': '2014-11-30', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 334,
#      'Members': [{'Name': '2014-12-01', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 335,
#      'Members': [{'Name': '2014-12-02', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 336,
#      'Members': [{'Name': '2014-12-03', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 337,
#      'Members': [{'Name': '2014-12-04', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 338,
#      'Members': [{'Name': '2014-12-05', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 339,
#      'Members': [{'Name': '2014-12-06', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 340,
#      'Members': [{'Name': '2014-12-07', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 341,
#      'Members': [{'Name': '2014-12-08', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 342,
#      'Members': [{'Name': '2014-12-09', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 343,
#      'Members': [{'Name': '2014-12-10', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 344,
#      'Members': [{'Name': '2014-12-11', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 345,
#      'Members': [{'Name': '2014-12-12', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 346,
#      'Members': [{'Name': '2014-12-13', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 347,
#      'Members': [{'Name': '2014-12-14', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 348,
#      'Members': [{'Name': '2014-12-15', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 349,
#      'Members': [{'Name': '2014-12-16', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 350,
#      'Members': [{'Name': '2014-12-17', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 351,
#      'Members': [{'Name': '2014-12-18', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 352,
#      'Members': [{'Name': '2014-12-19', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 353,
#      'Members': [{'Name': '2014-12-20', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 354,
#      'Members': [{'Name': '2014-12-21', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 355,
#      'Members': [{'Name': '2014-12-22', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 356,
#      'Members': [{'Name': '2014-12-23', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 357,
#      'Members': [{'Name': '2014-12-24', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 358,
#      'Members': [{'Name': '2014-12-25', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 359,
#      'Members': [{'Name': '2014-12-26', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 360,
#      'Members': [{'Name': '2014-12-27', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal': 361,
#      'Members': [{'Name': '2014-12-28', 'Element': {'Type': 'Numeric'}}]},
#     {'Ordinal':
#   {'Value': 9539, 'RuleDerived': False},
#   {'Value': 20652, 'RuleDerived': False},
#   {'Value': 3932, 'RuleDerived': False},
#   {'Value': 7124, 'RuleDerived': False},
#   {'Value': 21082, 'RuleDerived': False},
#   {'Value': 4054, 'RuleDerived': False},
#   {'Value': 7018, 'RuleDerived': False},
#   {'Value': 14057, 'RuleDerived': False},
#   {'Value': 2264, 'RuleDerived': False},
#   {'Value': 5938, 'RuleDerived': False},
#   {'Value': 13272, 'RuleDerived': False},
#   {'Value': 1710, 'RuleDerived': False},
#   {'Value': 4737, 'RuleDerived': False},
#   {'Value': 8116, 'RuleDerived': False},
#   {'Value': 3091, 'RuleDerived': False},
#   {'Value': 4083, 'RuleDerived': False},
#   {'Value': 16691, 'RuleDerived': False},
#   {'Value': 2801, 'RuleDerived': False},
#   {'Value': 5528, 'RuleDerived': False},
#   {'Value': 16694, 'RuleDerived': False},
#   {'Value': 3581, 'RuleDerived': False},
#   {'Value': 5982, 'RuleDerived': False},
#   {'Value': 20611, 'RuleDerived': False},
#   {'Value': 3424, 'RuleDerived': False},
#   {'Value': 7235, 'RuleDerived': False},
#   {'Value': 17806, 'RuleDerived': False},
#   {'Value': 3708, 'RuleDerived': False},
#   {'Value': 6345, 'RuleDerived': False},
#   {'Value': 12682, 'RuleDerived': False},
#   {'Value': 2504, 'RuleDerived': False},
#   {'Value': 5561, 'RuleDerived': False},
#   {'Value': 15669, 'RuleDerived': False},
#   {'Value': 1665, 'RuleDerived': False},
#   {'Value': 5560, 'RuleDerived': False},
#   {'Value': 23031, 'RuleDerived': False},
#   {'Value': 1993, 'RuleDerived': False},
#   {'Value': 9142, 'RuleDerived': False},
#   {'Value': 25580, 'RuleDerived': False},
#   {'Value': 3200, 'RuleDerived': False},
#   {'Value': 8127, 'RuleDerived': False},
#   {'Value': 3675, 'RuleDerived': False},
#   {'Value': 2635, 'RuleDerived': False},
#   {'Value': 1424, 'RuleDerived': False},
#   {'Value': 3945, 'RuleDerived': False},
#   {'Value': 706, 'RuleDerived': False},
#   {'Value': 1843, 'RuleDerived': False},
#   {'Value': 8378, 'RuleDerived': False},
#   {'Value': 1265, 'RuleDerived': False},
#   {'Value': 2609, 'RuleDerived': False},
#   {'Value': 8183, 'RuleDerived': False},
#   {'Value': 2706, 'RuleDerived': False},
#   {'Value': 3651, 'RuleDerived': False},
#   {'Value': 12384, 'RuleDerived': False},
#   ...]}

# %%
# Extract cube name from response
raw_json['Cube']
# Out:
# {'Name': 'Bike Shares',
#  'Dimensions': [{'Name': 'Version'},
#   {'Name': 'Date'},
#   {'Name': 'City'},
#   {'Name': 'Bike Shares Measure'}]}

# %% [markdown]
# ## Getting cell values
# - **Use Case**: sometimes you are only interested in the cell values. Skipping the elements in the response increases performance
# - **Note**: Fast and light

# %%
# %time
values = tm1.cubes.cells.execute_view_values(cube_name=cube_name, view_name=view_name, private=False)
# Out:
# Wall time: 0 ns

# %%
# extract first ten values
first_ten = list(values)[0:10]
# print first ten values
print(first_ten)
# Out:
# []

# %% [markdown]
# ## Getting row elements and cell values only
# - **Use Case**: sometimes elements in columns and titles are irrelevant. Skipping these elements in the response increases performance
# - **Note**: Faster than querying everything

# %%
rows_and_values = tm1.cubes.cells.execute_view_rows_and_values(
    cube_name=cube_name, 
    view_name=view_name, 
    private=False,
    element_unique_names=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-d27c46373c41> in <module>
# ----> 1 rows_and_values = tm1.cubes.cells.execute_view_rows_and_values(
#       2     cube_name=cube_name,
#       3     view_name=view_name,
#       4     private=False,
#       5     element_unique_names=False)
#
# AttributeError: 'CellService' object has no attribute 'execute_view_rows_and_values'

# %%
for row_elements, values_by_row in rows_and_values.items():
    print(row_elements, values_by_row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-adeec9d2fe66> in <module>
# ----> 1 for row_elements, values_by_row in rows_and_values.items():
#       2     print(row_elements, values_by_row)
#
# NameError: name 'rows_and_values' is not defined

# %% [markdown]
# ## Getting data with attributes values
# To get attributes values, you will need to get the data from an MDX query

# %%
mdx = """
    WITH MEMBER [Bike Shares Measure].[City Alias] AS [}ElementAttributes_City].([}ElementAttributes_City].[City Alias])
    SELECT 
    NON EMPTY {[Date].Members}*{TM1SubsetAll([City])} ON ROWS, 
    NON EMPTY {[Bike Shares Measure].[Count], [Bike Shares Measure].[City Alias] } ON COLUMNS 
    FROM [Bike Shares] 
    WHERE ([Version].[Actual],[Bike Shares Measure].[Count])"""

# get table'ish dataframe
data = tm1.cubes.cells.execute_mdx(mdx)

# %%
#Build pandas dataframe
df = Utils.build_pandas_dataframe_from_cellset(data, multiindex=False)
print(df)
# Out:
#       Version        Date        City Bike Shares Measure         Values
# 1      Actual        2014     Chicago          City Alias
# 0      Actual        2014     Chicago               Count        2454634
# 3      Actual        2014         NYC          City Alias  New York City
# 2      Actual        2014         NYC               Count        8081216
# 7      Actual        2014  Total City          City Alias
# 6      Actual        2014  Total City               Count       13449000
# 5      Actual        2014  Washington          City Alias
# 4      Actual        2014  Washington               Count        2913150
# 9      Actual     2014-01     Chicago          City Alias
# 8      Actual     2014-01     Chicago               Count          25076
# 11     Actual     2014-01         NYC          City Alias  New York City
# 10     Actual     2014-01         NYC               Count         300400
# 15     Actual     2014-01  Total City          City Alias
# 14     Actual     2014-01  Total City               Count         438173
# 13     Actual     2014-01  Washington          City Alias
# 12     Actual     2014-01  Washington               Count         112697
# 17     Actual  2014-01-01     Chicago          City Alias
# 16     Actual  2014-01-01     Chicago               Count            123
# 19     Actual  2014-01-01         NYC          City Alias  New York City
# 18     Actual  2014-01-01         NYC               Count           6059
# 23     Actual  2014-01-01  Total City          City Alias
# 22     Actual  2014-01-01  Total City               Count           9193
# 21     Actual  2014-01-01  Washington          City Alias
# 20     Actual  2014-01-01  Washington               Count           3011
# 25     Actual  2014-01-02     Chicago          City Alias
# 24     Actual  2014-01-02     Chicago               Count            112
# 27     Actual  2014-01-02         NYC          City Alias  New York City
# 26     Actual  2014-01-02         NYC               Count           8600
# 31     Actual  2014-01-02  Total City          City Alias
# 30     Actual  2014-01-02  Total City               Count          12028
# ...       ...         ...         ...                 ...            ...
#            Total City                    17923
#            Washington                     3088
# 2017-12-30 Chicago                         548
#            NYC         New York City      5956
#            Total City                     8380
#            Washington                     1876
# 2017-12-31 Chicago                         651
#            NYC         New York City      6569
#            Total City                     8657
#            Washington                     1437
#
# [6052 rows x 2 columns]

# %% [markdown]
# ## Part 3: Reading from APIs
# ### Getting data from a web service, introduction to a JSON file
# The code below has been extracted from this article: [Upload weather data from web service](https://code.cubewise.com/tm1py-help-content/upload-weather-data-from-web-services-into-planning-analytics)

# %%
#library for HTTP / REST Request against Webservices
import requests
#standard library for JSON parsing, manipulation
import json

# %%
# Define constants
STATION = 'GHCND:USW00014732'
FROM, TO = '2017-01-01', '2017-01-04'
HEADERS = {"token": 'yyqEBOAbHVbtXkfAmZuPNfnSXvdfyhgn'}

# %%
url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?' \
      'datasetid=GHCND&' \
      'startdate=' + FROM + '&' \
      'enddate=' + TO + '&' \
      'limit=1000&' \
      'datatypeid=TMIN&' \
      'datatypeid=TAVG&' \
      'datatypeid=TMAX&' \
      'stationid=' + STATION

print(url)
# Out:
# https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&startdate=2017-01-01&enddate=2017-01-04&limit=1000&datatypeid=TMIN&datatypeid=TAVG&datatypeid=TMAX&stationid=GHCND:USW00014732

# %%
#Execute the URL against the NOAA API to get the results
#Prettyprint first three items from result-set

response = requests.get(url, headers=HEADERS).json()
results = response["results"]   

print(json.dumps(results[0:3], indent=2))
# Out:
# [
#   {
#     "date": "2017-01-01T00:00:00",
#     "datatype": "TAVG",
#     "station": "GHCND:USW00014732",
#     "attributes": "H,,S,",
#     "value": 80
#   },
#   {
#     "date": "2017-01-01T00:00:00",
#     "datatype": "TMAX",
#     "station": "GHCND:USW00014732",
#     "attributes": ",,W,2400",
#     "value": 94
#   },
#   {
#     "date": "2017-01-01T00:00:00",
#     "datatype": "TMIN",
#     "station": "GHCND:USW00014732",
#     "attributes": ",,W,2400",
#     "value": 39
#   }
# ]

# %%
#Rearrange the data
cells = dict()

for record in results:
    value = record['value'] / 10
    coordinates = ("Actual", record['date'][0:10], "NYC", record['datatype'])
    cells[coordinates] = value

# %%
for coordinate, value in cells.items():
    print(coordinate, value)
# Out:
# ('Actual', '2017-01-01', 'NYC', 'TAVG') 8.0
# ('Actual', '2017-01-01', 'NYC', 'TMAX') 9.4
# ('Actual', '2017-01-01', 'NYC', 'TMIN') 3.9
# ('Actual', '2017-01-02', 'NYC', 'TAVG') 4.4
# ('Actual', '2017-01-02', 'NYC', 'TMAX') 5.6
# ('Actual', '2017-01-02', 'NYC', 'TMIN') 3.3
# ('Actual', '2017-01-03', 'NYC', 'TAVG') 5.6
# ('Actual', '2017-01-03', 'NYC', 'TMAX') 8.3
# ('Actual', '2017-01-03', 'NYC', 'TMIN') 4.4
# ('Actual', '2017-01-04', 'NYC', 'TAVG') 8.2
# ('Actual', '2017-01-04', 'NYC', 'TMAX') 12.2
# ('Actual', '2017-01-04', 'NYC', 'TMIN') 2.2

# %%
# Write values back to TM1
tm1.cubes.cells.write_values("Weather Data", cells)
# Out:
# <Response [204]>
